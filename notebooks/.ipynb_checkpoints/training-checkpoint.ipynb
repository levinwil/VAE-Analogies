# %%
# %load_ext autoreload
# %autoreload 2
import sys 
sys.path.append('../scripts')
from model import VAE
from utils import load_mnist, load_birds
import matplotlib.pyplot as plt
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
X_train, X_test, y_train, y_test = load_mnist()

# %%
i = 1
X_train = X_train[np.where(y_train <= i)[0]]
y_train = y_train[np.where(y_train <= i)[0]]
X_test = X_test[np.where(y_test <= i)[0]]
y_test = y_test[np.where(y_test <= i)[0]]

# %%
vae = VAE(input_shape = X_train.shape[1:],
          kernel_size = 3,
          filters = 4,
          latent_dim = 3,
          lr = .01,
          std = 4)
# Out:
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Metrics:
# COMET INFO:                       batch: 20
# COMET INFO:                   epoch_end: 199
# COMET INFO:                        loss: 0.1103905985508703
# COMET INFO:         mean_absolute_error: 0.049702353699021345
# COMET INFO:                        size: 512
# COMET INFO:                        step: 4600
# COMET INFO:                    val_loss: 0.11156631342849115
# COMET INFO:     val_mean_absolute_error: 0.05033957977627052
# COMET INFO:   Other:
# COMET INFO:     trainable_params: 20548
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/levinwil/mnist/7ccf24c7b5794d1386e4d2fcc75a1367

# %%
vae.train(X_train, epochs = 200)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-116-b61af4e4ee2c> in <module>()
# ----> 1 vae.train(X_train, epochs = 200)
#
# ~/Documents/Projects/VAE/scripts/model.py in train(self, x_train, epochs, batch_size, val_p)
#     112                 callbacks = [checkpoint],
#     113                 validation_split = val_p,
# --> 114                 shuffle = True)
#     115         return self.vae
#     116
#
# ~/miniconda3/lib/python3.6/site-packages/comet_ml/monkey_patching.py in wrapper(*args, **kwargs)
#     241                     )
#     242
# --> 243         return_value = original(*args, **kwargs)
#     244
#     245         # Call after callbacks once we have the return value
#
# ...

# %%
vae.load_weights('../weights/best_mnist.hdf5')

# %%
for i in range(50, 100, 5):
    plt.imshow(X_test[i, :, :, 0])
    plt.show()
    im = vae.reconstruct(X_test[i:(i+1), :, :])[0, :, :, 0]
    plt.imshow(im)
    plt.show()

# %%
vae.plot_encoding(X_train[:10000], y_train[:10000])

# %%
for i in range(len(y_test)):
    if y_test[i] == 0:
        print(i)
        plt.imshow(X_test[i, :, :, 0])
        plt.show()
# Out:
# 1
# 3
# 4
# 6
# 7
# 14
# 16
# 17
# 22
# 24
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-83-554f8523f9ed> in <module>()
#       3         print(i)
#       4         plt.imshow(X_test[i, :, :, 0])
# ----> 5         plt.show()
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# ~/miniconda3/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# ~/miniconda3/lib/python3.6/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
# ...

# %%
vae.analogy(X_test[5], X_test[0], X_test[0])
# Out:
# Is to
# As
# Is to
