# %%
# %load_ext autoreload
# %autoreload 2
import sys 
sys.path.append('../scripts')
from model import VAE
from utils import load_mnist, load_birds
import matplotlib.pyplot as plt
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
X_train, X_test, y_train, y_test = load_mnist()

# %%
i = 2
X_train = X_train[np.where(y_train <= i)[0]]
y_train = y_train[np.where(y_train <= i)[0]]
X_test = X_test[np.where(y_test <= i)[0]]
y_test = y_test[np.where(y_test <= i)[0]]

# %%
vae = VAE(input_shape = X_train.shape[1:], std = 2)
# Out:
# COMET INFO: ----------------------------
# COMET INFO: Comet.ml Experiment Summary:
# COMET INFO:   Metrics:
# COMET INFO:                       batch: 20
# COMET INFO:                   epoch_end: 69
# COMET INFO:                        loss: 0.11077386924971153
# COMET INFO:         mean_absolute_error: 0.0499848581113184
# COMET INFO:                        size: 512
# COMET INFO:                        step: 1610
# COMET INFO:                    val_loss: 0.11164810786048728
# COMET INFO:     val_mean_absolute_error: 0.049891075050280426
# COMET INFO:   Other:
# COMET INFO:     trainable_params: 20548
# COMET INFO: ----------------------------
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/levinwil/mnist/e3c5641cc5344ba180d79436386028d7

# %%
vae.train(X_train, epochs = 400)
# Out:
# Train on 16760 samples, validate on 1863 samples
# Epoch 1/400
# 16760/16760 [==============================] - 4s 264us/step - loss: 0.1405 - mean_absolute_error: 0.0686 - val_loss: 0.1426 - val_mean_absolute_error: 0.0703
#
# Epoch 00001: val_loss improved from inf to 0.14259, saving model to ../weights/best_mnist.hdf5
# Epoch 2/400
# 16760/16760 [==============================] - 4s 263us/step - loss: 0.1409 - mean_absolute_error: 0.0689 - val_loss: 0.1421 - val_mean_absolute_error: 0.0693
#
# Epoch 00002: val_loss improved from 0.14259 to 0.14211, saving model to ../weights/best_mnist.hdf5
# Epoch 3/400
# 16760/16760 [==============================] - 4s 264us/step - loss: 0.1403 - mean_absolute_error: 0.0684 - val_loss: 0.1419 - val_mean_absolute_error: 0.0693
#
# Epoch 00003: val_loss improved from 0.14211 to 0.14192, saving model to ../weights/best_mnist.hdf5
# Epoch 4/400
# 16760/16760 [==============================] - 5s 270us/step - loss: 0.1400 - mean_absolute_error: 0.0683 - val_loss: 0.1424 - val_mean_absolute_error: 0.0685
#
# Epoch 00004: val_loss did not improve from 0.14192
# Epoch 5/400
# 16760/16760 [==============================] - 5s 324us/step - loss: 0.1404 - mean_absolute_error: 0.0685 - val_loss: 0.1415 - val_mean_absolute_error: 0.0690
#
# Epoch 00005: val_loss improved from 0.14192 to 0.14152, saving model to ../weights/best_mnist.hdf5
# Epoch 6/400
# 16760/16760 [==============================] - 5s 324us/step - loss: 0.1402 - mean_absolute_error: 0.0684 - val_loss: 0.1420 - val_mean_absolute_error: 0.0705
#
# Epoch 00006: val_loss did not improve from 0.14152
# Epoch 7/400
# 16760/16760 [==============================] - 5s 318us/step - loss: 0.1401 - mean_absolute_error: 0.0683 - val_loss: 0.1419 - val_mean_absolute_error: 0.0691
#
# Epoch 00007: val_loss did not improve from 0.14152
# Epoch 8/400
# 16760/16760 [==============================] - 5s 320us/step - loss: 0.1400 - mean_absolute_error: 0.0683 - val_loss: 0.1416 - val_mean_absolute_error: 0.0689
#
# Epoch 00008: val_loss did not improve from 0.14152
# Epoch 9/400
# 16760/16760 [==============================] - 5s 317us/step - loss: 0.1401 - mean_absolute_error: 0.0684 - val_loss: 0.1418 - val_mean_absolute_error: 0.0692
#
# Epoch 00009: val_loss did not improve from 0.14152
# Epoch 10/400
# 16760/16760 [==============================] - 5s 318us/step - loss: 0.1405 - mean_absolute_error: 0.0685 - val_loss: 0.1422 - val_mean_absolute_error: 0.0700
#
# Epoch 00010: val_loss did not improve from 0.14152
# Epoch 11/400
# 16760/16760 [==============================] - 5s 317us/step - loss: 0.1399 - mean_absolute_error: 0.0683 - val_loss: 0.1424 - val_mean_absolute_error: 0.0678
#
# Epoch 00011: val_loss did not improve from 0.14152
# Epoch 12/400
# 16760/16760 [==============================] - 5s 293us/step - loss: 0.1399 - mean_absolute_error: 0.0681 - val_loss: 0.1411 - val_mean_absolute_error: 0.0689
#
# Epoch 00012: val_loss improved from 0.14152 to 0.14114, saving model to ../weights/best_mnist.hdf5
# Epoch 13/400
# 16760/16760 [==============================] - 5s 322us/step - loss: 0.1396 - mean_absolute_error: 0.0680 - val_loss: 0.1420 - val_mean_absolute_error: 0.0690
#
# Epoch 00013: val_loss did not improve from 0.14114
# Epoch 14/400
# 16760/16760 [==============================] - 5s 318us/step - loss: 0.1399 - mean_absolute_error: 0.0682 - val_loss: 0.1427 - val_mean_absolute_error: 0.0695
#
# Epoch 00014: val_loss did not improve from 0.14114
# Epoch 15/400
# 16760/16760 [==============================] - 5s 321us/step - loss: 0.1401 - mean_absolute_error: 0.0684 - val_loss: 0.1415 - val_mean_absolute_error: 0.0686
#
# Epoch 00015: val_loss did not improve from 0.14114
# Epoch 16/400
# 16760/16760 [==============================] - 5s 324us/step - loss: 0.1394 - mean_absolute_error: 0.0678 - val_loss: 0.1413 - val_mean_absolute_error: 0.0693
#
# Epoch 00016: val_loss did not improve from 0.14114
# Epoch 17/400
# 16760/16760 [==============================] - 5s 319us/step - loss: 0.1400 - mean_absolute_error: 0.0683 - val_loss: 0.1415 - val_mean_absolute_error: 0.0697
#
# Epoch 00017: val_loss did not improve from 0.14114
# Epoch 18/400
# 16760/16760 [==============================] - 5s 320us/step - loss: 0.1397 - mean_absolute_error: 0.0680 - val_loss: 0.1416 - val_mean_absolute_error: 0.0686
#
# Epoch 00018: val_loss did not improve from 0.14114
# Epoch 19/400
# 16760/16760 [==============================] - 5s 318us/step - loss: 0.1395 - mean_absolute_error: 0.0679 - val_loss: 0.1419 - val_mean_absolute_error: 0.0688
#
# Epoch 00019: val_loss did not improve from 0.14114
# Epoch 20/400
# 16760/16760 [==============================] - 5s 326us/step - loss: 0.1395 - mean_absolute_error: 0.0679 - val_loss: 0.1414 - val_mean_absolute_error: 0.0694
#
# Epoch 00020: val_loss did not improve from 0.14114
# Epoch 21/400
# 16760/16760 [==============================] - 5s 319us/step - loss: 0.1392 - mean_absolute_error: 0.0678 - val_loss: 0.1413 - val_mean_absolute_error: 0.0697
#
# Epoch 00021: val_loss did not improve from 0.14114
# Epoch 22/400
# 16760/16760 [==============================] - 5s 324us/step - loss: 0.1392 - mean_absolute_error: 0.0677 - val_loss: 0.1442 - val_mean_absolute_error: 0.0711
#
# Epoch 00022: val_loss did not improve from 0.14114
# Epoch 23/400
# 16760/16760 [==============================] - 5s 320us/step - loss: 0.1392 - mean_absolute_error: 0.0677 - val_loss: 0.1417 - val_mean_absolute_error: 0.0706
#
# Epoch 00023: val_loss did not improve from 0.14114
# Epoch 24/400
# 16760/16760 [==============================] - 5s 320us/step - loss: 0.1394 - mean_absolute_error: 0.0679 - val_loss: 0.1414 - val_mean_absolute_error: 0.0685
#
# Epoch 00024: val_loss did not improve from 0.14114
# Epoch 25/400
# 16760/16760 [==============================] - 5s 326us/step - loss: 0.1391 - mean_absolute_error: 0.0676 - val_loss: 0.1417 - val_mean_absolute_error: 0.0686
#
# Epoch 00025: val_loss did not improve from 0.14114
# Epoch 26/400
# 16760/16760 [==============================] - 5s 320us/step - loss: 0.1397 - mean_absolute_error: 0.0680 - val_loss: 0.1412 - val_mean_absolute_error: 0.0688
#
# Epoch 00026: val_loss did not improve from 0.14114
# Epoch 27/400
# 16760/16760 [==============================] - 5s 320us/step - loss: 0.1391 - mean_absolute_error: 0.0677 - val_loss: 0.1416 - val_mean_absolute_error: 0.0699
#
# Epoch 00027: val_loss did not improve from 0.14114
# Epoch 28/400
# 16760/16760 [==============================] - 5s 326us/step - loss: 0.1390 - mean_absolute_error: 0.0675 - val_loss: 0.1407 - val_mean_absolute_error: 0.0688
#
# Epoch 00028: val_loss improved from 0.14114 to 0.14072, saving model to ../weights/best_mnist.hdf5
# Epoch 29/400
# 16760/16760 [==============================] - 5s 322us/step - loss: 0.1398 - mean_absolute_error: 0.0681 - val_loss: 0.1416 - val_mean_absolute_error: 0.0684
#
# Epoch 00029: val_loss did not improve from 0.14072
# Epoch 30/400
# 16760/16760 [==============================] - 5s 321us/step - loss: 0.1390 - mean_absolute_error: 0.0676 - val_loss: 0.1422 - val_mean_absolute_error: 0.0683
#
# Epoch 00030: val_loss did not improve from 0.14072
# Epoch 31/400
# 16760/16760 [==============================] - 5s 325us/step - loss: 0.1390 - mean_absolute_error: 0.0675 - val_loss: 0.1406 - val_mean_absolute_error: 0.0684
#
# Epoch 00031: val_loss improved from 0.14072 to 0.14055, saving model to ../weights/best_mnist.hdf5
# Epoch 32/400
# 16760/16760 [==============================] - 5s 321us/step - loss: 0.1393 - mean_absolute_error: 0.0677 - val_loss: 0.1418 - val_mean_absolute_error: 0.0708
#
# Epoch 00032: val_loss did not improve from 0.14055
# Epoch 33/400
# 16760/16760 [==============================] - 5s 323us/step - loss: 0.1389 - mean_absolute_error: 0.0675 - val_loss: 0.1413 - val_mean_absolute_error: 0.0687
#
# Epoch 00033: val_loss did not improve from 0.14055
# Epoch 34/400
# 16760/16760 [==============================] - 5s 309us/step - loss: 0.1388 - mean_absolute_error: 0.0675 - val_loss: 0.1409 - val_mean_absolute_error: 0.0682
#
# Epoch 00034: val_loss did not improve from 0.14055
# Epoch 35/400
# 16760/16760 [==============================] - 5s 316us/step - loss: 0.1385 - mean_absolute_error: 0.0672 - val_loss: 0.1407 - val_mean_absolute_error: 0.0692
#
# Epoch 00035: val_loss did not improve from 0.14055
# Epoch 36/400
# 16760/16760 [==============================] - 5s 311us/step - loss: 0.1388 - mean_absolute_error: 0.0675 - val_loss: 0.1405 - val_mean_absolute_error: 0.0683
#
# Epoch 00036: val_loss improved from 0.14055 to 0.14045, saving model to ../weights/best_mnist.hdf5
# Epoch 37/400
# 16760/16760 [==============================] - 5s 315us/step - loss: 0.1389 - mean_absolute_error: 0.0675 - val_loss: 0.1409 - val_mean_absolute_error: 0.0695
#
# Epoch 00037: val_loss did not improve from 0.14045
# Epoch 38/400
# 16760/16760 [==============================] - 5s 312us/step - loss: 0.1388 - mean_absolute_error: 0.0675 - val_loss: 0.1415 - val_mean_absolute_error: 0.0682
#
# Epoch 00038: val_loss did not improve from 0.14045
# Epoch 39/400
# 16760/16760 [==============================] - 5s 314us/step - loss: 0.1387 - mean_absolute_error: 0.0674 - val_loss: 0.1403 - val_mean_absolute_error: 0.0680
#
# Epoch 00039: val_loss improved from 0.14045 to 0.14031, saving model to ../weights/best_mnist.hdf5
# Epoch 40/400
# 16760/16760 [==============================] - 5s 314us/step - loss: 0.1387 - mean_absolute_error: 0.0674 - val_loss: 0.1405 - val_mean_absolute_error: 0.0686
#
# Epoch 00040: val_loss did not improve from 0.14031
# Epoch 41/400
# 16760/16760 [==============================] - 5s 312us/step - loss: 0.1386 - mean_absolute_error: 0.0673 - val_loss: 0.1406 - val_mean_absolute_error: 0.0680
#
# Epoch 00041: val_loss did not improve from 0.14031
# Epoch 42/400
# 16760/16760 [==============================] - 5s 318us/step - loss: 0.1386 - mean_absolute_error: 0.0672 - val_loss: 0.1422 - val_mean_absolute_error: 0.0703
#
# Epoch 00042: val_loss did not improve from 0.14031
# Epoch 43/400
# 16760/16760 [==============================] - 5s 315us/step - loss: 0.1387 - mean_absolute_error: 0.0673 - val_loss: 0.1418 - val_mean_absolute_error: 0.0703
#
# Epoch 00043: val_loss did not improve from 0.14031
# Epoch 44/400
# 16760/16760 [==============================] - 5s 314us/step - loss: 0.1388 - mean_absolute_error: 0.0674 - val_loss: 0.1404 - val_mean_absolute_error: 0.0687
#
# Epoch 00044: val_loss did not improve from 0.14031
# Epoch 45/400
# 16760/16760 [==============================] - 5s 317us/step - loss: 0.1388 - mean_absolute_error: 0.0674 - val_loss: 0.1413 - val_mean_absolute_error: 0.0676
#
# Epoch 00045: val_loss did not improve from 0.14031
# Epoch 46/400
# 16760/16760 [==============================] - 5s 310us/step - loss: 0.1384 - mean_absolute_error: 0.0671 - val_loss: 0.1405 - val_mean_absolute_error: 0.0684
#
# Epoch 00046: val_loss did not improve from 0.14031
# Epoch 47/400
# 16760/16760 [==============================] - 5s 313us/step - loss: 0.1383 - mean_absolute_error: 0.0671 - val_loss: 0.1404 - val_mean_absolute_error: 0.0678
#
# Epoch 00047: val_loss did not improve from 0.14031
# Epoch 48/400
# 16760/16760 [==============================] - 5s 315us/step - loss: 0.1384 - mean_absolute_error: 0.0671 - val_loss: 0.1406 - val_mean_absolute_error: 0.0687
#
# Epoch 00048: val_loss did not improve from 0.14031
# Epoch 49/400
# 16760/16760 [==============================] - 5s 309us/step - loss: 0.1380 - mean_absolute_error: 0.0669 - val_loss: 0.1403 - val_mean_absolute_error: 0.0693
#
# Epoch 00049: val_loss improved from 0.14031 to 0.14026, saving model to ../weights/best_mnist.hdf5
# Epoch 50/400
# 16760/16760 [==============================] - 5s 308us/step - loss: 0.1383 - mean_absolute_error: 0.0671 - val_loss: 0.1410 - val_mean_absolute_error: 0.0697
#
# Epoch 00050: val_loss did not improve from 0.14026
# Epoch 51/400
# 16760/16760 [==============================] - 5s 315us/step - loss: 0.1393 - mean_absolute_error: 0.0677 - val_loss: 0.1416 - val_mean_absolute_error: 0.0675
#
# Epoch 00051: val_loss did not improve from 0.14026
# Epoch 52/400
# 16760/16760 [==============================] - 5s 309us/step - loss: 0.1385 - mean_absolute_error: 0.0671 - val_loss: 0.1407 - val_mean_absolute_error: 0.0682
#
# Epoch 00052: val_loss did not improve from 0.14026
# Epoch 53/400
# 16760/16760 [==============================] - 5s 314us/step - loss: 0.1383 - mean_absolute_error: 0.0670 - val_loss: 0.1411 - val_mean_absolute_error: 0.0694
#
# Epoch 00053: val_loss did not improve from 0.14026
# Epoch 54/400
# 16760/16760 [==============================] - 5s 315us/step - loss: 0.1380 - mean_absolute_error: 0.0669 - val_loss: 0.1405 - val_mean_absolute_error: 0.0680
#
# Epoch 00054: val_loss did not improve from 0.14026
# Epoch 55/400
# 16760/16760 [==============================] - 5s 315us/step - loss: 0.1381 - mean_absolute_error: 0.0670 - val_loss: 0.1401 - val_mean_absolute_error: 0.0673
#
# Epoch 00055: val_loss improved from 0.14026 to 0.14006, saving model to ../weights/best_mnist.hdf5
# Epoch 56/400
# 16760/16760 [==============================] - 5s 314us/step - loss: 0.1380 - mean_absolute_error: 0.0668 - val_loss: 0.1401 - val_mean_absolute_error: 0.0675
#
# Epoch 00056: val_loss did not improve from 0.14006
# Epoch 57/400
# 16760/16760 [==============================] - 5s 298us/step - loss: 0.1384 - mean_absolute_error: 0.0671 - val_loss: 0.1406 - val_mean_absolute_error: 0.0694
#
# Epoch 00057: val_loss did not improve from 0.14006
# Epoch 58/400
# 16760/16760 [==============================] - 5s 313us/step - loss: 0.1385 - mean_absolute_error: 0.0672 - val_loss: 0.1404 - val_mean_absolute_error: 0.0686
#
# Epoch 00058: val_loss did not improve from 0.14006
# Epoch 59/400
# 16760/16760 [==============================] - 5s 316us/step - loss: 0.1382 - mean_absolute_error: 0.0669 - val_loss: 0.1406 - val_mean_absolute_error: 0.0686
#
# Epoch 00059: val_loss did not improve from 0.14006
# Epoch 60/400
# 16760/16760 [==============================] - 5s 316us/step - loss: 0.1382 - mean_absolute_error: 0.0669 - val_loss: 0.1411 - val_mean_absolute_error: 0.0688
#
# Epoch 00060: val_loss did not improve from 0.14006
# Epoch 61/400
# 16760/16760 [==============================] - 5s 317us/step - loss: 0.1382 - mean_absolute_error: 0.0670 - val_loss: 0.1433 - val_mean_absolute_error: 0.0672
#
# Epoch 00061: val_loss did not improve from 0.14006
# Epoch 62/400
# 16760/16760 [==============================] - 5s 319us/step - loss: 0.1385 - mean_absolute_error: 0.0671 - val_loss: 0.1405 - val_mean_absolute_error: 0.0683
#
# Epoch 00062: val_loss did not improve from 0.14006
# Epoch 63/400
# 16760/16760 [==============================] - 5s 310us/step - loss: 0.1378 - mean_absolute_error: 0.0668 - val_loss: 0.1404 - val_mean_absolute_error: 0.0683
#
# Epoch 00063: val_loss did not improve from 0.14006
# Epoch 64/400
# 16760/16760 [==============================] - 5s 314us/step - loss: 0.1378 - mean_absolute_error: 0.0667 - val_loss: 0.1399 - val_mean_absolute_error: 0.0673
#
# Epoch 00064: val_loss improved from 0.14006 to 0.13986, saving model to ../weights/best_mnist.hdf5
# Epoch 65/400
# 16760/16760 [==============================] - 5s 322us/step - loss: 0.1387 - mean_absolute_error: 0.0671 - val_loss: 0.1409 - val_mean_absolute_error: 0.0700
#
# Epoch 00065: val_loss did not improve from 0.13986
# Epoch 66/400
# 16760/16760 [==============================] - 5s 320us/step - loss: 0.1384 - mean_absolute_error: 0.0671 - val_loss: 0.1402 - val_mean_absolute_error: 0.0681
#
# Epoch 00066: val_loss did not improve from 0.13986
# Epoch 67/400
# 16760/16760 [==============================] - 5s 316us/step - loss: 0.1379 - mean_absolute_error: 0.0668 - val_loss: 0.1397 - val_mean_absolute_error: 0.0679
#
# Epoch 00067: val_loss improved from 0.13986 to 0.13973, saving model to ../weights/best_mnist.hdf5
# Epoch 68/400
# 16760/16760 [==============================] - 5s 318us/step - loss: 0.1378 - mean_absolute_error: 0.0667 - val_loss: 0.1404 - val_mean_absolute_error: 0.0690
#
# Epoch 00068: val_loss did not improve from 0.13973
# Epoch 69/400
# 16760/16760 [==============================] - 5s 313us/step - loss: 0.1382 - mean_absolute_error: 0.0669 - val_loss: 0.1400 - val_mean_absolute_error: 0.0691
#
# Epoch 00069: val_loss did not improve from 0.13973
# Epoch 70/400
# 16760/16760 [==============================] - 5s 320us/step - loss: 0.1376 - mean_absolute_error: 0.0666 - val_loss: 0.1401 - val_mean_absolute_error: 0.0680
#
# Epoch 00070: val_loss did not improve from 0.13973
# Epoch 71/400
# 16760/16760 [==============================] - 5s 310us/step - loss: 0.1377 - mean_absolute_error: 0.0666 - val_loss: 0.1405 - val_mean_absolute_error: 0.0671
#
# Epoch 00071: val_loss did not improve from 0.13973
# Epoch 72/400
# 16760/16760 [==============================] - 5s 318us/step - loss: 0.1378 - mean_absolute_error: 0.0666 - val_loss: 0.1400 - val_mean_absolute_error: 0.0679
#
# Epoch 00072: val_loss did not improve from 0.13973
# Epoch 73/400
# 16760/16760 [==============================] - 5s 327us/step - loss: 0.1378 - mean_absolute_error: 0.0667 - val_loss: 0.1399 - val_mean_absolute_error: 0.0678
#
# Epoch 00073: val_loss did not improve from 0.13973
# Epoch 74/400
# 16760/16760 [==============================] - 5s 318us/step - loss: 0.1375 - mean_absolute_error: 0.0664 - val_loss: 0.1400 - val_mean_absolute_error: 0.0680
#
# Epoch 00074: val_loss did not improve from 0.13973
# Epoch 75/400
# 16760/16760 [==============================] - 5s 307us/step - loss: 0.1374 - mean_absolute_error: 0.0664 - val_loss: 0.1398 - val_mean_absolute_error: 0.0685
#
# Epoch 00075: val_loss did not improve from 0.13973
# Epoch 76/400
# 16760/16760 [==============================] - 5s 312us/step - loss: 0.1376 - mean_absolute_error: 0.0665 - val_loss: 0.1406 - val_mean_absolute_error: 0.0696
#
# Epoch 00076: val_loss did not improve from 0.13973
# Epoch 77/400
# 16760/16760 [==============================] - 5s 312us/step - loss: 0.1377 - mean_absolute_error: 0.0666 - val_loss: 0.1402 - val_mean_absolute_error: 0.0688
#
# Epoch 00077: val_loss did not improve from 0.13973
# Epoch 78/400
# 16760/16760 [==============================] - 5s 313us/step - loss: 0.1376 - mean_absolute_error: 0.0666 - val_loss: 0.1400 - val_mean_absolute_error: 0.0687
#
# Epoch 00078: val_loss did not improve from 0.13973
# Epoch 79/400
# 16760/16760 [==============================] - 5s 304us/step - loss: 0.1379 - mean_absolute_error: 0.0668 - val_loss: 0.1395 - val_mean_absolute_error: 0.0676
#
# Epoch 00079: val_loss improved from 0.13973 to 0.13946, saving model to ../weights/best_mnist.hdf5
# Epoch 80/400
# 16760/16760 [==============================] - 5s 293us/step - loss: 0.1376 - mean_absolute_error: 0.0665 - val_loss: 0.1394 - val_mean_absolute_error: 0.0674
#
# Epoch 00080: val_loss improved from 0.13946 to 0.13939, saving model to ../weights/best_mnist.hdf5
# Epoch 81/400
# 16760/16760 [==============================] - 5s 314us/step - loss: 0.1375 - mean_absolute_error: 0.0664 - val_loss: 0.1399 - val_mean_absolute_error: 0.0674
#
# Epoch 00081: val_loss did not improve from 0.13939
# Epoch 82/400
# 16760/16760 [==============================] - 5s 315us/step - loss: 0.1377 - mean_absolute_error: 0.0665 - val_loss: 0.1423 - val_mean_absolute_error: 0.0708
#
# Epoch 00082: val_loss did not improve from 0.13939
# Epoch 83/400
# 16760/16760 [==============================] - 5s 313us/step - loss: 0.1378 - mean_absolute_error: 0.0667 - val_loss: 0.1404 - val_mean_absolute_error: 0.0689
#
# Epoch 00083: val_loss did not improve from 0.13939
# Epoch 84/400
# 16760/16760 [==============================] - 5s 314us/step - loss: 0.1374 - mean_absolute_error: 0.0664 - val_loss: 0.1407 - val_mean_absolute_error: 0.0694
#
# Epoch 00084: val_loss did not improve from 0.13939
# Epoch 85/400
# 16760/16760 [==============================] - 5s 310us/step - loss: 0.1372 - mean_absolute_error: 0.0663 - val_loss: 0.1394 - val_mean_absolute_error: 0.0672
#
# Epoch 00085: val_loss improved from 0.13939 to 0.13936, saving model to ../weights/best_mnist.hdf5
# Epoch 86/400
# 16760/16760 [==============================] - 8s 467us/step - loss: 0.1373 - mean_absolute_error: 0.0662 - val_loss: 0.1396 - val_mean_absolute_error: 0.0686
#
# Epoch 00086: val_loss did not improve from 0.13936
# Epoch 87/400
# 16760/16760 [==============================] - 10s 606us/step - loss: 0.1379 - mean_absolute_error: 0.0667 - val_loss: 0.1419 - val_mean_absolute_error: 0.0675
#
# Epoch 00087: val_loss did not improve from 0.13936
# Epoch 88/400
# 16760/16760 [==============================] - 7s 390us/step - loss: 0.1376 - mean_absolute_error: 0.0665 - val_loss: 0.1398 - val_mean_absolute_error: 0.0674
#
# Epoch 00088: val_loss did not improve from 0.13936
# Epoch 89/400
# 16760/16760 [==============================] - 5s 326us/step - loss: 0.1371 - mean_absolute_error: 0.0662 - val_loss: 0.1396 - val_mean_absolute_error: 0.0676
#
# Epoch 00089: val_loss did not improve from 0.13936
# Epoch 90/400
# 16760/16760 [==============================] - 6s 342us/step - loss: 0.1371 - mean_absolute_error: 0.0662 - val_loss: 0.1398 - val_mean_absolute_error: 0.0686
#
# Epoch 00090: val_loss did not improve from 0.13936
# Epoch 91/400
# 16760/16760 [==============================] - 6s 339us/step - loss: 0.1372 - mean_absolute_error: 0.0663 - val_loss: 0.1404 - val_mean_absolute_error: 0.0691
#
# Epoch 00091: val_loss did not improve from 0.13936
# Epoch 92/400
# 16760/16760 [==============================] - 5s 321us/step - loss: 0.1372 - mean_absolute_error: 0.0662 - val_loss: 0.1401 - val_mean_absolute_error: 0.0683
#
# Epoch 00092: val_loss did not improve from 0.13936
# Epoch 93/400
# 16760/16760 [==============================] - 6s 330us/step - loss: 0.1375 - mean_absolute_error: 0.0665 - val_loss: 0.1411 - val_mean_absolute_error: 0.0669
#
# Epoch 00093: val_loss did not improve from 0.13936
# Epoch 94/400
# 16760/16760 [==============================] - 6s 328us/step - loss: 0.1372 - mean_absolute_error: 0.0662 - val_loss: 0.1399 - val_mean_absolute_error: 0.0685
#
# Epoch 00094: val_loss did not improve from 0.13936
# Epoch 95/400
# 16760/16760 [==============================] - 6s 363us/step - loss: 0.1371 - mean_absolute_error: 0.0662 - val_loss: 0.1393 - val_mean_absolute_error: 0.0675
#
# Epoch 00095: val_loss improved from 0.13936 to 0.13925, saving model to ../weights/best_mnist.hdf5
# Epoch 96/400
# 16760/16760 [==============================] - 6s 377us/step - loss: 0.1369 - mean_absolute_error: 0.0660 - val_loss: 0.1402 - val_mean_absolute_error: 0.0697
#
# Epoch 00096: val_loss did not improve from 0.13925
# Epoch 97/400
# 16760/16760 [==============================] - 8s 458us/step - loss: 0.1370 - mean_absolute_error: 0.0661 - val_loss: 0.1392 - val_mean_absolute_error: 0.0671
#
# Epoch 00097: val_loss improved from 0.13925 to 0.13919, saving model to ../weights/best_mnist.hdf5
# Epoch 98/400
# 16760/16760 [==============================] - 6s 360us/step - loss: 0.1377 - mean_absolute_error: 0.0665 - val_loss: 0.1400 - val_mean_absolute_error: 0.0685
#
# Epoch 00098: val_loss did not improve from 0.13919
# Epoch 99/400
# 16760/16760 [==============================] - 6s 331us/step - loss: 0.1372 - mean_absolute_error: 0.0662 - val_loss: 0.1399 - val_mean_absolute_error: 0.0688
#
# Epoch 00099: val_loss did not improve from 0.13919
# Epoch 100/400
# 16760/16760 [==============================] - 6s 344us/step - loss: 0.1370 - mean_absolute_error: 0.0662 - val_loss: 0.1392 - val_mean_absolute_error: 0.0672
#
# Epoch 00100: val_loss did not improve from 0.13919
# Epoch 101/400
# 16760/16760 [==============================] - 6s 356us/step - loss: 0.1370 - mean_absolute_error: 0.0661 - val_loss: 0.1392 - val_mean_absolute_error: 0.0669
#
# Epoch 00101: val_loss improved from 0.13919 to 0.13919, saving model to ../weights/best_mnist.hdf5
# Epoch 102/400
# 16760/16760 [==============================] - 6s 363us/step - loss: 0.1369 - mean_absolute_error: 0.0660 - val_loss: 0.1393 - val_mean_absolute_error: 0.0675
#
# Epoch 00102: val_loss did not improve from 0.13919
# Epoch 103/400
# 16760/16760 [==============================] - 6s 387us/step - loss: 0.1375 - mean_absolute_error: 0.0664 - val_loss: 0.1422 - val_mean_absolute_error: 0.0707
#
# Epoch 00103: val_loss did not improve from 0.13919
# Epoch 104/400
# 16760/16760 [==============================] - 7s 392us/step - loss: 0.1374 - mean_absolute_error: 0.0663 - val_loss: 0.1399 - val_mean_absolute_error: 0.0683
#
# Epoch 00104: val_loss did not improve from 0.13919
# Epoch 105/400
# 16760/16760 [==============================] - 6s 378us/step - loss: 0.1371 - mean_absolute_error: 0.0662 - val_loss: 0.1397 - val_mean_absolute_error: 0.0686
#
# Epoch 00105: val_loss did not improve from 0.13919
# Epoch 106/400
# 16760/16760 [==============================] - 6s 343us/step - loss: 0.1367 - mean_absolute_error: 0.0659 - val_loss: 0.1392 - val_mean_absolute_error: 0.0677
#
# Epoch 00106: val_loss improved from 0.13919 to 0.13916, saving model to ../weights/best_mnist.hdf5
# Epoch 107/400
# 16760/16760 [==============================] - 5s 311us/step - loss: 0.1381 - mean_absolute_error: 0.0668 - val_loss: 0.1402 - val_mean_absolute_error: 0.0667
#
# Epoch 00107: val_loss did not improve from 0.13916
# Epoch 108/400
# 16760/16760 [==============================] - 5s 314us/step - loss: 0.1370 - mean_absolute_error: 0.0661 - val_loss: 0.1399 - val_mean_absolute_error: 0.0687
#
# Epoch 00108: val_loss did not improve from 0.13916
# Epoch 109/400
# 16760/16760 [==============================] - 5s 320us/step - loss: 0.1370 - mean_absolute_error: 0.0661 - val_loss: 0.1397 - val_mean_absolute_error: 0.0668
#
# Epoch 00109: val_loss did not improve from 0.13916
# Epoch 110/400
# 16760/16760 [==============================] - 6s 350us/step - loss: 0.1370 - mean_absolute_error: 0.0661 - val_loss: 0.1394 - val_mean_absolute_error: 0.0671
#
# Epoch 00110: val_loss did not improve from 0.13916
# Epoch 111/400
# 16760/16760 [==============================] - 6s 359us/step - loss: 0.1371 - mean_absolute_error: 0.0662 - val_loss: 0.1396 - val_mean_absolute_error: 0.0684
#
# Epoch 00111: val_loss did not improve from 0.13916
# Epoch 112/400
# 16760/16760 [==============================] - 6s 377us/step - loss: 0.1367 - mean_absolute_error: 0.0660 - val_loss: 0.1393 - val_mean_absolute_error: 0.0664
#
# Epoch 00112: val_loss did not improve from 0.13916
# Epoch 113/400
# 16760/16760 [==============================] - 7s 413us/step - loss: 0.1367 - mean_absolute_error: 0.0659 - val_loss: 0.1397 - val_mean_absolute_error: 0.0671
#
# Epoch 00113: val_loss did not improve from 0.13916
# Epoch 114/400
# 16760/16760 [==============================] - 6s 368us/step - loss: 0.1368 - mean_absolute_error: 0.0660 - val_loss: 0.1391 - val_mean_absolute_error: 0.0666
#
# Epoch 00114: val_loss improved from 0.13916 to 0.13911, saving model to ../weights/best_mnist.hdf5
# Epoch 115/400
# 16760/16760 [==============================] - 6s 335us/step - loss: 0.1369 - mean_absolute_error: 0.0660 - val_loss: 0.1390 - val_mean_absolute_error: 0.0671
#
# Epoch 00115: val_loss improved from 0.13911 to 0.13903, saving model to ../weights/best_mnist.hdf5
# Epoch 116/400
# 16760/16760 [==============================] - 6s 343us/step - loss: 0.1366 - mean_absolute_error: 0.0658 - val_loss: 0.1396 - val_mean_absolute_error: 0.0673
#
# Epoch 00116: val_loss did not improve from 0.13903
# Epoch 117/400
# 16760/16760 [==============================] - 5s 324us/step - loss: 0.1368 - mean_absolute_error: 0.0660 - val_loss: 0.1396 - val_mean_absolute_error: 0.0666
#
# Epoch 00117: val_loss did not improve from 0.13903
# Epoch 118/400
# 16760/16760 [==============================] - 6s 334us/step - loss: 0.1368 - mean_absolute_error: 0.0659 - val_loss: 0.1393 - val_mean_absolute_error: 0.0678
#
# Epoch 00118: val_loss did not improve from 0.13903
# Epoch 119/400
# 16760/16760 [==============================] - 6s 367us/step - loss: 0.1370 - mean_absolute_error: 0.0661 - val_loss: 0.1398 - val_mean_absolute_error: 0.0680
#
# Epoch 00119: val_loss did not improve from 0.13903
# Epoch 120/400
# 16760/16760 [==============================] - 5s 307us/step - loss: 0.1371 - mean_absolute_error: 0.0661 - val_loss: 0.1400 - val_mean_absolute_error: 0.0688
#
# Epoch 00120: val_loss did not improve from 0.13903
# Epoch 121/400
# 16760/16760 [==============================] - 5s 319us/step - loss: 0.1373 - mean_absolute_error: 0.0662 - val_loss: 0.1399 - val_mean_absolute_error: 0.0690
#
# Epoch 00121: val_loss did not improve from 0.13903
# Epoch 122/400
# 16760/16760 [==============================] - 5s 323us/step - loss: 0.1366 - mean_absolute_error: 0.0659 - val_loss: 0.1409 - val_mean_absolute_error: 0.0699
#
# Epoch 00122: val_loss did not improve from 0.13903
# Epoch 123/400
# 16760/16760 [==============================] - 7s 401us/step - loss: 0.1371 - mean_absolute_error: 0.0662 - val_loss: 0.1401 - val_mean_absolute_error: 0.0675
#
# Epoch 00123: val_loss did not improve from 0.13903
# Epoch 124/400
# 16760/16760 [==============================] - 6s 334us/step - loss: 0.1370 - mean_absolute_error: 0.0661 - val_loss: 0.1394 - val_mean_absolute_error: 0.0679
#
# Epoch 00124: val_loss did not improve from 0.13903
# Epoch 125/400
# 16760/16760 [==============================] - 5s 325us/step - loss: 0.1368 - mean_absolute_error: 0.0659 - val_loss: 0.1398 - val_mean_absolute_error: 0.0672
#
# Epoch 00125: val_loss did not improve from 0.13903
# Epoch 126/400
# 16760/16760 [==============================] - 5s 314us/step - loss: 0.1365 - mean_absolute_error: 0.0658 - val_loss: 0.1395 - val_mean_absolute_error: 0.0676
#
# Epoch 00126: val_loss did not improve from 0.13903
# Epoch 127/400
# 16760/16760 [==============================] - 5s 327us/step - loss: 0.1366 - mean_absolute_error: 0.0658 - val_loss: 0.1399 - val_mean_absolute_error: 0.0683
#
# Epoch 00127: val_loss did not improve from 0.13903
# Epoch 128/400
# 16760/16760 [==============================] - 5s 326us/step - loss: 0.1367 - mean_absolute_error: 0.0658 - val_loss: 0.1391 - val_mean_absolute_error: 0.0677
#
# Epoch 00128: val_loss did not improve from 0.13903
# Epoch 129/400
# 16760/16760 [==============================] - 5s 322us/step - loss: 0.1369 - mean_absolute_error: 0.0660 - val_loss: 0.1392 - val_mean_absolute_error: 0.0671
#
# Epoch 00129: val_loss did not improve from 0.13903
# Epoch 130/400
# 16760/16760 [==============================] - 5s 325us/step - loss: 0.1366 - mean_absolute_error: 0.0658 - val_loss: 0.1393 - val_mean_absolute_error: 0.0670
#
# Epoch 00130: val_loss did not improve from 0.13903
# Epoch 131/400
# 16760/16760 [==============================] - 5s 316us/step - loss: 0.1370 - mean_absolute_error: 0.0660 - val_loss: 0.1410 - val_mean_absolute_error: 0.0673
#
# Epoch 00131: val_loss did not improve from 0.13903
# Epoch 132/400
# 16760/16760 [==============================] - 5s 326us/step - loss: 0.1367 - mean_absolute_error: 0.0658 - val_loss: 0.1395 - val_mean_absolute_error: 0.0680
#
# Epoch 00132: val_loss did not improve from 0.13903
# Epoch 133/400
# 16760/16760 [==============================] - 6s 329us/step - loss: 0.1364 - mean_absolute_error: 0.0657 - val_loss: 0.1396 - val_mean_absolute_error: 0.0683
#
# Epoch 00133: val_loss did not improve from 0.13903
# Epoch 134/400
# 16760/16760 [==============================] - 6s 330us/step - loss: 0.1366 - mean_absolute_error: 0.0659 - val_loss: 0.1387 - val_mean_absolute_error: 0.0666
#
# Epoch 00134: val_loss improved from 0.13903 to 0.13873, saving model to ../weights/best_mnist.hdf5
# Epoch 135/400
# 16760/16760 [==============================] - 6s 329us/step - loss: 0.1367 - mean_absolute_error: 0.0658 - val_loss: 0.1392 - val_mean_absolute_error: 0.0681
#
# Epoch 00135: val_loss did not improve from 0.13873
# Epoch 136/400
# 16760/16760 [==============================] - 6s 333us/step - loss: 0.1367 - mean_absolute_error: 0.0658 - val_loss: 0.1390 - val_mean_absolute_error: 0.0671
#
# Epoch 00136: val_loss did not improve from 0.13873
# Epoch 137/400
#  2048/16760 [==>...........................] - ETA: 4s - loss: 0.1354 - mean_absolute_error: 0.0657
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-260-4c0e9ba43b9a> in <module>()
# ----> 1 vae.train(X_train, epochs = 400)
#
# ~/Documents/Projects/VAE/scripts/model.py in train(self, x_train, epochs, batch_size, val_p)
#     119                 callbacks = [checkpoint],
#     120                 validation_split = val_p,
# --> 121                 shuffle = True)
#     122         return self.vae
#     123
#
# ~/miniconda3/lib/python3.6/site-packages/comet_ml/monkey_patching.py in wrapper(*args, **kwargs)
#     241                     )
#     242
# --> 243         return_value = original(*args, **kwargs)
#     244
#     245         # Call after callbacks once we have the return value
#
# ~/miniconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# ~/miniconda3/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1234                         ins_batch[i] = ins_batch[i].toarray()
#    1235
# -> 1236                     outs = f(ins_batch)
#    1237                     if not isinstance(outs, list):
#    1238                         outs = [outs]
#
# ~/miniconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2480         session = get_session()
#    2481         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2482                               **self.session_kwargs)
#    2483         return updated[:len(self.outputs)]
#    2484
#
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
vae.load_weights('../weights/best_mnist.hdf5')

# %%
for i in range(0, 50, 5):
    plt.imshow(X_test[i, :, :, 0])
    plt.show()
    im = vae.reconstruct(X_test[i:(i+1), :, :])[0, :, :, 0]
    plt.imshow(im)
    plt.show()

# %%
vae.plot_encoding(X_train[:10000], y_train[:10000])

# %%
for i in range(len(y_test)):
    if y_test[i] == 0:
        print(i)
        plt.imshow(X_test[i, :, :, 0])
        plt.show()
# Out:
# 2
# 4
# 5
# 7
# 8
# 19
# 21
# 22
# 30
# 34
# 36
# 41
# 44
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-261-554f8523f9ed> in <module>()
#       3         print(i)
#       4         plt.imshow(X_test[i, :, :, 0])
# ----> 5         plt.show()
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# ~/miniconda3/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# ~/miniconda3/lib/python3.6/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     296             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297         else:
# --> 298             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299             if not format_dict:
#     300                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/miniconda3/lib/python3.6/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# ~/miniconda3/lib/python3.6/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/miniconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/miniconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/miniconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2051                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2052                     bbox_inches = self.figure.get_tightbbox(renderer,
# -> 2053                             bbox_extra_artists=bbox_artists)
#    2054                     pad = kwargs.pop("pad_inches", None)
#    2055                     if pad is None:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2268
#    2269         for a in artists:
# -> 2270             bbox = a.get_tightbbox(renderer)
#    2271             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2272                 bb.append(bbox)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer)
#    1140         ticks_to_draw = self._update_ticks(renderer)
#    1141
# -> 1142         self._update_label_position(renderer)
#    1143
#    1144         # go back to just this axis's tick labels
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    1932         # get bounding boxes for this axis and any siblings
#    1933         # that have been set by `fig.align_xlabels()`
# -> 1934         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    1935
#    1936         x, y = self.label.get_position()
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    1916         # if we want to align labels from other axes:
#    1917         for nn, axx in enumerate(grp.get_siblings(self.axes)):
# -> 1918             ticks_to_draw = axx.xaxis._update_ticks(renderer)
#    1919             tlb, tlb2 = axx.xaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    1920             bboxes.extend(tlb)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in _update_ticks(self, renderer)
#    1021
#    1022         interval = self.get_view_interval()
# -> 1023         tick_tups = list(self.iter_ticks())  # iter_ticks calls the locator
#    1024         if self._smart_bounds and tick_tups:
#    1025             # handle inverted limits
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in iter_ticks(self)
#     965         Iterate through all of the major and minor ticks.
#     966         """
# --> 967         majorLocs = self.major.locator()
#     968         majorTicks = self.get_major_ticks(len(majorLocs))
#     969         self.major.formatter.set_locs(majorLocs)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/ticker.py in __call__(self)
#    1983     def __call__(self):
#    1984         vmin, vmax = self.axis.get_view_interval()
# -> 1985         return self.tick_values(vmin, vmax)
#    1986
#    1987     def tick_values(self, vmin, vmax):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/ticker.py in tick_values(self, vmin, vmax)
#    1991         vmin, vmax = mtransforms.nonsingular(
#    1992             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 1993         locs = self._raw_ticks(vmin, vmax)
#    1994
#    1995         prune = self._prune
#
# ~/.local/lib/python3.6/site-packages/matplotlib/ticker.py in _raw_ticks(self, vmin, vmax)
#    1930         if self._nbins == 'auto':
#    1931             if self.axis is not None:
# -> 1932                 nbins = np.clip(self.axis.get_tick_space(),
#    1933                                 max(1, self._min_n_ticks - 1), 9)
#    1934             else:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in get_tick_space(self)
#    2152         ends = self.axes.transAxes.transform([[0, 0], [1, 0]])
#    2153         length = ((ends[1][0] - ends[0][0]) / self.axes.figure.dpi) * 72
# -> 2154         tick = self._get_tick(True)
#    2155         # There is a heuristic here that the aspect ratio of tick text
#    2156         # is no more than 3:1
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1816         else:
#    1817             tick_kw = self._minor_tick_kw
# -> 1818         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1819
#    1820     def _get_label(self):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     173
#     174         self.tick1line = self._get_tick1line()
# --> 175         self.tick2line = self._get_tick2line()
#     176         self.gridline = self._get_gridline()
#     177
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick2line(self)
#     482                           markersize=self._size,
#     483                           markeredgewidth=self._width,
# --> 484                           zorder=self._zorder)
#     485
#     486         l.set_transform(self.axes.get_xaxis_transform(which='tick2'))
#
# ~/.local/lib/python3.6/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     399         self._markerfacecoloralt = None
#     400
# --> 401         self.set_markerfacecolor(markerfacecolor)
#     402         self.set_markerfacecoloralt(markerfacecoloralt)
#     403         self.set_markeredgecolor(markeredgecolor)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/lines.py in set_markerfacecolor(self, fc)
#    1157         if fc is None:
#    1158             fc = 'auto'
# -> 1159         if np.any(self._markerfacecolor != fc):
#    1160             self.stale = True
#    1161         self._markerfacecolor = fc
#
# ~/miniconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in any(a, axis, out, keepdims)
#    2011
#    2012     """
# -> 2013     return _wrapreduction(a, np.logical_or, 'any', axis, None, out, keepdims=keepdims)
#    2014
#    2015
#
# ~/miniconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      81                 return reduction(axis=axis, out=out, **passkwargs)
#      82
# ---> 83     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      84
#      85
#
# KeyboardInterrupt:

# %%
vae.analogy(X_test[12], X_test[1], X_test[4])
# Out:
# Is to
# As
# Is to
